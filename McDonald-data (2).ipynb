# %% [markdown]
# ## McDonalds Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\rehit\Downloads\Mcdonald .csv')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df['Category'].unique()
# Out:
# array(['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads',
#        'Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea',
#        'Smoothies & Shakes'], dtype=object)

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
a=df['Category'].value_counts()
a
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Beverages             27
# Chicken & Fish        27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %% [markdown]
# ## 1.Food Category that have the highest and lowest varieties

# %%
#Category which has max variety
df.groupby('Category')['Category'].count().idxmax()
# Out:
# 'Coffee & Tea'

# %%
#Category which has min variety
df.groupby('Category')['Category'].count().idxmin()
# Out:
# 'Salads'

# %% [markdown]
# ## 2.Outliers

# %%
df.boxplot(figsize=(40,20))

# %% [markdown]
# ## 3.Category that contributes to max percent of Cholestrol in a diet

# %%
df.groupby('Category')['Cholesterol (% Daily Value)'].mean().idxmax()
# Out:
# 'Breakfast'

# %% [markdown]
# ## 4.Item which contributes max to sodium intake

# %%
df.groupby('Item')['Sodium'].max().idxmax()
# Out:
# 'Chicken McNuggets (40 piece)'

# %% [markdown]
# ## 5.Food items which contains most saturated fat

# %%
df.groupby('Item')['Saturated Fat'].max().sort_values().tail(4)
# Out:
# Item
# Frappé Chocolate Chip (Large)                  20.0
# McFlurry with M&M’s Candies (Medium)           20.0
# Chicken McNuggets (40 piece)                   20.0
# Big Breakfast with Hotcakes (Large Biscuit)    20.0
# Name: Saturated Fat, dtype: float64
